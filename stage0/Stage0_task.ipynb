# %% [markdown]
# ## TASK
# ### Use any data structure of your choice to organize the following information
# ##### Your names
# ##### Your slack username
# ##### Your email
# ##### Your hobby
# ##### Your countries
# ##### Your discipline
# ##### Your preferred programming language
# ##### Don’t use functions, loops, conditionals or any complex concepts
# ##### Your code should include a final print statement that prints the organized output in a logical and understandable way.

# %%
# SOLUTION
#Using Dictionary to store team members' information

Team_information = {
    "Vivian": {
        "Name": "Vivian Korir", 
        "Slack Username": "Korir",
        "Email": "vckorirr.9@gmail.com",
        "Hobby": "Art",
        "Country": "Scotland",
        "Discipline": "Medical Biotechnology",
        "Preferred programming Language": "Python"},
    
    "Abdulkabir": {
        "Name": "Abdulkabir Omeiza Abdulmalik", 
        "Slack Username": "Abdulkabir",
        "Email": "abdulmalikabdulkabir2019@gmail.com",
        "Hobby": "Playing football and taking nature walks", 
        "Countries": "Nigeria and Germany",
        "Discipline": "Plant Microbial Ecology",
        "Preferred Programming": "Python"},
   
     "Samuel": {
        "Name": "Samuel Oseni",
        "Slack Username": "Samslango",
        "Email": "Samueloseniayo@gmail.com",
        "Hobby": "Playing video games, reading & solving problems",
        "Country": "Nigeria",
        "Discipline": "Physiology",
        "Preferred Programming Language": "Python"}, 
    
    "Bashidoshi": {
        "Name": "Musa Bashidoshi Bawa",
        "Slack Username": "Bashidoshi",
        "Email": "musabashibawa@gmail.com",
        "Hobby": "Playing guitar",
        "Country": "Nigeria",
        "Discipline": "Genetics and Biotechnology",
        "Preferred programming language": "Python"}
}

##This prints the information of all the team members
print(f"""
Team Glutamine Member Information

--- Team Leader ---
Name: {Team_information['Vivian']['Name']}
Slack Username: {Team_information['Vivian']['Slack Username']}
Email: {Team_information['Vivian']['Email']}
Hobby: {Team_information['Vivian']['Hobby']}
Country: {Team_information['Vivian']['Country']}
Discipline: {Team_information['Vivian']['Discipline']}
Preferred Programming Language: {Team_information['Vivian']['Preferred programming Language']}

--- Team member 1 ---
Name: {Team_information['Abdulkabir']['Name']}
Slack Username: {Team_information['Abdulkabir']['Slack Username']}
Email: {Team_information['Abdulkabir']['Email']}
Hobby: {Team_information['Abdulkabir']['Hobby']}
Countries: {Team_information['Abdulkabir']['Countries']}
Discipline: {Team_information['Abdulkabir']['Discipline']}
Preferred Programming: {Team_information['Abdulkabir']['Preferred Programming']}

--- Team member 2 ---
Name: {Team_information['Samuel']['Name']}
Slack Username: {Team_information['Samuel']['Slack Username']}
Email: {Team_information['Samuel']['Email']}
Hobby: {Team_information['Samuel']['Hobby']}
Country: {Team_information['Samuel']['Country']}
Discipline: {Team_information['Samuel']['Discipline']}
Preferred Programming Language: {Team_information['Samuel']['Preferred Programming Language']}


--- Team member 3 ---
Name: {Team_information['Bashidoshi']['Name']}
Slack Username: {Team_information['Bashidoshi']['Slack Username']}
Email: {Team_information['Bashidoshi']['Email']}
Hobby: {Team_information['Bashidoshi']['Hobby']}
Country: {Team_information['Bashidoshi']['Country']}
Discipline: {Team_information['Bashidoshi']['Discipline']}
Preferred Programming Language: {Team_information['Bashidoshi']['Preferred programming language']}
""")
# Out:
# Team Glutamine Member Information
#
# --- Team Leader ---
# Name: Vivian Korir
# Slack Username: Korir
# Email: vckorirr.9@gmail.com
# Hobby: Art
# Country: Scotland
# Discipline: Medical Biotechnology
# Preferred Programming Language: Python
#
# --- Team member 1 ---
# Name: Abdulkabir Omeiza Abdulmalik
# Slack Username: Abdulkabir
# Email: abdulmalikabdulkabir2019@gmail.com
# Hobby: Playing football and taking nature walks
# Countries: Nigeria and Germany
# Discipline: Plant Microbial Ecology
# Preferred Programming: Python
#
# --- Team member 2 ---
# Name: Samuel Oseni
# Slack Username: Samslango
# Email: Samueloseniayo@gmail.com
# Hobby: Playing video games, reading & solving problems
# Country: Nigeria
# Discipline: Physiology
# Preferred Programming Language: Python
#
#
# --- Team member 3 ---
# Name: Musa Bashidoshi Bawa
# Slack Username: Bashidoshi
# Email: musabashibawa@gmail.com
# Hobby: Playing guitar
# Country: Nigeria
# Discipline: Genetics and Biotechnology
# ...
